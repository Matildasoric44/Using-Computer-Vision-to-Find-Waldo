# %% [markdown]
# #Where's Waldo Annotations
#
# In this notebook has the annotations of all 19 original images for Waldo.

# %% [markdown]
# ##Importing modules, dependencies, and data
#
# ---
#
# Importing all modules used in this analysis and mounting our google drive.

# %%
#imports
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import cv2
from PIL import Image
import zipfile
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Annotating

# %% [markdown]
# Here we are first finding the path to the orginal images from the drive they are tored. We are then annotating all 19 images with a rectangle on the figure of Waldo.

# %%
dir = '/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/'

# %%
path = dir

# %%
original_img = dir + 'original-images/'

# %% [markdown]
# Image 1 Annotation

# %%
#importing the image to be read
img = cv2.imread(os.path.join(original_img,'1.jpg')) 
imageRectangle = img.copy()
#define the starting and end points of the rectangle
start_point =(700,500)
end_point =(760,600)
#draw the rectangle
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow(imageRectangle)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_1.png',imageRectangle)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 2 Annotation

# %%
img2 = cv2.imread(os.path.join(original_img,'2.jpg')) 
imageRectangle2 = img2.copy()
start_point =(70,510)
end_point =(120,580)
cv2.rectangle(imageRectangle2, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle2)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_2.png',imageRectangle2)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 3 Annotation

# %%
img3 = cv2.imread(os.path.join(original_img,'3.jpg')) 
imageRectangle3 = img3.copy()
start_point =(1380,450)
end_point =(1440,510)
cv2.rectangle(imageRectangle3, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle3)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_3.png',imageRectangle3)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 4 Annotation

# %%
img4 = cv2.imread(os.path.join(original_img,'4.jpg')) 
imageRectangle4 = img4.copy()
start_point =(1480,270)
end_point =(1520,320)
cv2.rectangle(imageRectangle4, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle4)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_4.png',imageRectangle4)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 5 Annotation

# %%
img5 = cv2.imread(os.path.join(original_img,'5.jpg')) 
imageRectangle5 = img5.copy()
start_point =(1570,590)
end_point =(1630,660)
cv2.rectangle(imageRectangle5, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_5.png',imageRectangle5)
cv2_imshow( imageRectangle5)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 6 Annotation

# %%
img6 = cv2.imread(os.path.join(original_img,'6.jpg')) 
imageRectangle6 = img6.copy()
start_point =(1710,400)
end_point =(1760,470)
cv2.rectangle(imageRectangle6, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle6)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_6.png',imageRectangle6)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 7 Annotation

# %%
img7 = cv2.imread(os.path.join(original_img,'7.jpg')) 
imageRectangle7 = img7.copy()
start_point =(785,940)
end_point =(890,1050)
cv2.rectangle(imageRectangle7, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle7)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_7.png',imageRectangle7)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 8 Annotation

# %%
img8 = cv2.imread(os.path.join(original_img,'8.jpg')) 
imageRectangle8 = img8.copy()
start_point =(1150,270)
end_point =(1200,340)
cv2.rectangle(imageRectangle8, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle8)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_8.png',imageRectangle8)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 9 Annotation

# %%
img9 = cv2.imread(os.path.join(original_img,'9.jpg')) 
imageRectangle9 = img9.copy()
start_point =(220,720)
end_point =(280,770)
cv2.rectangle(imageRectangle9, start_point, end_point, (255, 0, 0), thickness= 6, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle9)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_9.png',imageRectangle9)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 10 Annotation

# %%
img10 = cv2.imread(os.path.join(original_img,'10.jpg')) 
imageRectangle10 = img.copy()
start_point =(700,450)
end_point =(750,500)
cv2.rectangle(imageRectangle10, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle10)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_10.png',imageRectangle10)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 11 Annotation

# %%
img11 = cv2.imread(os.path.join(original_img,'11.jpg')) 
imageRectangle11 = img11.copy()
start_point =(450,1520)
end_point =(500,1570)
cv2.rectangle(imageRectangle11, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle11)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_11.png',imageRectangle11)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 12 Annotation

# %%
img12 = cv2.imread(os.path.join(original_img,'12.jpg')) 
imageRectangle12 = img12.copy()
start_point =(830,510)
end_point =(880,580)
cv2.rectangle(imageRectangle12, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle12)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_12.png',imageRectangle12)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 13 Annotation

# %%
img13 = cv2.imread(os.path.join(original_img,'13.jpg')) 
imageRectangle13 = img13.copy()
start_point =(915,260)
end_point =(950,310)
cv2.rectangle(imageRectangle13, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle13)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_13.png',imageRectangle13)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 14 Annotation

# %%
img14 = cv2.imread(os.path.join(original_img,'14.jpg')) 
imageRectangle14 = img14.copy()
start_point =(180,1860)
end_point =(245,1950)
cv2.rectangle(imageRectangle14, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle14)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_14.png',imageRectangle14)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 15 Annotation

# %%
img15 = cv2.imread(os.path.join(original_img,'15.jpg')) 
imageRectangle15 = img15.copy()
start_point =(290,420)
end_point =(330,470)
cv2.rectangle(imageRectangle15, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle15)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_15.png',imageRectangle15)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 16 Annotation

# %%
img16 = cv2.imread(os.path.join(original_img,'16.jpg')) 
imageRectangle16 = img16.copy()
start_point =(1920,750)
end_point =(1970,800)
cv2.rectangle(imageRectangle16, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle16)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_16.png',imageRectangle16)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 17 Annotation

# %%
img17 = cv2.imread(os.path.join(original_img,'17.jpg')) 
imageRectangle17 = img17.copy()
start_point =(740,240)
end_point =(790,310)
cv2.rectangle(imageRectangle17, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle17)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_17.png',imageRectangle17)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 18 Annotation

# %%
img18 = cv2.imread(os.path.join(original_img,'18.jpg')) 
imageRectangle18 = img18.copy()
start_point =(1260,70)
end_point =(1300,120)
cv2.rectangle(imageRectangle18, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle18)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_18.png',imageRectangle18)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Image 19 Annotation

# %%
img19 = cv2.imread(os.path.join(original_img,'19.jpg')) 
imageRectangle19 = img19.copy()
start_point =(320,615)
end_point =(360,660)
cv2.rectangle(imageRectangle19, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
cv2_imshow( imageRectangle19)
cv2.imwrite('/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/waldo_annotations/waldo_19.png',imageRectangle19)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ###Shaping each annotated image as an array and saving each as a csv file.

# %%
img1 = np.array(Image.open(dir + "waldo_annotations/waldo_1.png"))
img2 = np.array(Image.open(dir + "waldo_annotations/waldo_2.png"))
img3 = np.array(Image.open(dir + "waldo_annotations/waldo_3.png"))
img4 = np.array(Image.open(dir + "waldo_annotations/waldo_4.png"))
img5 = np.array(Image.open(dir + "waldo_annotations/waldo_5.png"))
img6 = np.array(Image.open(dir + "waldo_annotations/waldo_6.png"))
img7 = np.array(Image.open(dir + "waldo_annotations/waldo_7.png"))
img8 = np.array(Image.open(dir + "waldo_annotations/waldo_8.png"))
img9 = np.array(Image.open(dir + "waldo_annotations/waldo_9.png"))
img10 = np.array(Image.open(dir + "waldo_annotations/waldo_10.png"))
img11 = np.array(Image.open(dir + "waldo_annotations/waldo_11.png"))
img12 = np.array(Image.open(dir + "waldo_annotations/waldo_12.png"))
img13 = np.array(Image.open(dir + "waldo_annotations/waldo_13.png"))
img14 = np.array(Image.open(dir + "waldo_annotations/waldo_14.png"))
img15 = np.array(Image.open(dir + "waldo_annotations/waldo_15.png"))
img16 = np.array(Image.open(dir + "waldo_annotations/waldo_16.png"))
img17 = np.array(Image.open(dir + "waldo_annotations/waldo_17.png"))
img18 = np.array(Image.open(dir + "waldo_annotations/waldo_18.png"))
img19 = np.array(Image.open(dir + "waldo_annotations/waldo_19.png"))

# %%
def csvWriter(fil_name, nparray):
  example = nparray.tolist()
  with open(fil_name+'.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerows(example)

# %%
csvWriter(dir + "waldo_annotations/waldo_1.png", img1)
csvWriter(dir + "waldo_annotations/waldo_2", img2)
csvWriter(dir + "waldo_annotations/waldo_3", img3)
csvWriter(dir + "waldo_annotations/waldo_4", img4)
csvWriter(dir + "waldo_annotations/waldo_5", img5)
csvWriter(dir + "waldo_annotations/waldo_6", img6)
csvWriter(dir + "waldo_annotations/waldo_7", img7)
csvWriter(dir + "waldo_annotations/waldo_8", img8)
csvWriter(dir + "waldo_annotations/waldo_9", img9)
csvWriter(dir + "waldo_annotations/waldo_10", img10)
csvWriter(dir + "waldo_annotations/waldo_11", img11)
csvWriter(dir + "waldo_annotations/waldo_12", img12)
csvWriter(dir + "waldo_annotations/waldo_13", img13)
csvWriter(dir + "waldo_annotations/waldo_14", img14)
csvWriter(dir + "waldo_annotations/waldo_15", img15)
csvWriter(dir + "waldo_annotations/waldo_16", img16)
csvWriter(dir + "waldo_annotations/waldo_17", img17)
csvWriter(dir + "waldo_annotations/waldo_18", img18)
csvWriter(dir + "waldo_annotations/waldo_19", img19)

# %% [markdown]
# ###Putting each image csv into a list to save as a zip file.::

# %%
list_files_cooler2 = [dir + 'waldo_annotations/waldo_1.csv', dir + 'waldo_annotations/waldo_2.csv', 
              dir + 'waldo_annotations/waldo_3.csv', dir + 'waldo_annotations/waldo_4.csv', 
              dir + 'waldo_annotations/waldo_5.csv', dir + 'waldo_annotations/waldo_6.csv', 
              dir + 'waldo_annotations/waldo_7.csv', dir + 'waldo_annotations/waldo_8.csv', 
              dir + 'waldo_annotations/waldo_9.csv', dir + 'waldo_annotations/waldo_10.csv', 
              dir + 'waldo_annotations/waldo_11.csv', dir + 'waldo_annotations/waldo_12.csv', 
              dir + 'waldo_annotations/waldo_13.csv', dir + 'waldo_annotations/waldo_14.csv',
              dir + 'waldo_annotations/waldo_15.csv', dir + 'waldo_annotations/waldo_16.csv', 
              dir + 'waldo_annotations/waldo_17.csv', dir + 'waldo_annotations/waldo_18.csv',
              dir + 'waldo_annotations/waldo_19.csv']


with zipfile.ZipFile('Waldo.zip', 'w') as zipF:
    for file in list_files_cooler2:
        zipF.write(file)
